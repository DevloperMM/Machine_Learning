# %% [markdown]
# # SMOTE (Synthetic Minority Oversampling Technique)
# SMOTE (Synthetic Minority Over-sampling Technique) is a technique used in machine learning to address imbalanced datasets where the minority class has significantly fewer instances than the majority class. SMOTE involves generating synthetic instances of the minority class by interpolating between existing instances.

# %% [markdown]
# ### NOTE : In this code we had made a dataset first and then apply the SMOTE rather we can also use some already available datasets available of the library.

# %%
from sklearn.datasets import make_classification

# %%
x, y = make_classification(n_samples=500,
                          n_redundant=0,
                          n_features=2,
                          n_clusters_per_class=1,
                          weights=[0.85],
                          random_state=12)

# %%
x.shape
# Out:
# (500, 2)

# %%
len(y[y==1])
# Out:
# 78

# %%
import pandas as pd

df1 = pd.DataFrame(x, columns=['f1','f2'])
df2 = pd.DataFrame(y, columns=['target'])
final_df = pd.concat([df1,df2],axis=1)
final_df
# Out:
#            f1        f2  target
# 0   -0.560929 -2.229746       0
# 1   -1.225052 -0.538468       0
# 2   -1.810050 -1.456371       0
# 3   -0.644562 -1.857017       0
# 4    0.151321 -0.764229       0
# ..        ...       ...     ...
# 495 -0.701250 -2.690555       0
# 496 -1.944703  1.031470       0
# 497 -1.299768 -0.546961       0
# 498 -1.077850 -0.394916       0
# 499 -1.808949  0.540361       0
#
# [500 rows x 3 columns]

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    422
# 1     78
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'], final_df['f2'], c=final_df['target'])
plt.show()

# %% [markdown]
# ## Here we apply SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
# transform the dataset

oversample = SMOTE()
x,y = oversample.fit_resample(final_df[['f1','f2']],final_df['target'])

# %%
x.shape
# Out:
# (844, 2)

# %%
y.shape
# Out:
# (844,)

# %%
len(y[y==0])
# Out:
# 422

# %%
len(y[y==1])
# Out:
# 422

# %%
df1 = pd.DataFrame(x, columns=['f1','f2'])
df2 = pd.DataFrame(y, columns=['target'])
oversample_df = pd.concat([df1,df2],axis=1)

# %%
plt.scatter(oversample_df['f1'], oversample_df['f2'], c=oversample_df['target'])
plt.show()
