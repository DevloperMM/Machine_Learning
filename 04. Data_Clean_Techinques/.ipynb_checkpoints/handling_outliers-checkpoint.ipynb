# %% [markdown]
# ## 5-number summary
# 1. Minimum - 0 %ile
# 2. Quantile1 - 25 %ile
# 3. Median - 50 %ile
# 4. Quantile3 - 75 %ile
# 5. Maximum - 100 %ile

# %%
import numpy as np

# %%
marks = [45, 32, 56, 75, 89, 54, 32, 89, 90, 87, 67, 54, 45, 98, 99, 67, 74, 600, 700]
minimum, Q1, median, Q3, maximum = np.quantile(marks, [0,0.25,0.50,0.75,1.0])

# %%
np.percentile(lst_marks, 25)
# Out:
# 54.0

# %%
minimum, Q1, median, Q3, maximum
# Out:
# (32.0, 54.0, 74.0, 89.5, 700.0)

# %%
IQR = Q3 - Q1 # Inter Quantile Range
IQR
# Out:
# 35.5

# %%
low_fence = Q1 - 1.5*(IQR)
high_fence = Q3 + 1.5*(IQR)

# %%
low_fence
# Out:
# 0.75

# %%
high_fence
# Out:
# 142.75

# %%
outlier = []
for i in marks:
    if i >= low_fence and i <= high_fence:
        pass
    else:
        print(i, 'is an outlier')
        outlier.append(i)
outlier
# Out:
# 600 is an outlier
# 700 is an outlier
# [600, 700]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(marks)
plt.show()

# %%
marks=[-100,-200,45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,150,170,180]

# %%
sns.boxplot(marks)
plt.show()

# %%
marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]

# %%
sns.boxplot(marks)
plt.show()
